# %%
import pandas as pd
df=pd.read_csv('D:\dressdataset.csv')
df.head()
# Out:
#      Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852        2114        2274        2491        2660        2727
# 1  1212192089         151         275         570         750         813
# 2  1190380701           6           7           7           7           8
# 3   966005983        1005        1128        1326        1455        1507
# 4   876339541         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 0        2887        2930       3119       3204  ...       3554     3624.0
# 1        1066        1164       1558       1756  ...       2710     2942.0
# 2           8           9         10         10  ...         11       11.0
# 3        1621        1637       1723       1746  ...       1878     1892.0
# 4        1559        1570       1638       1655  ...       2032     2156.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    237
# 28-09-2013      0
# 30-09-2013    273
# 10-02-2013    275
# 10-04-2013    274
# 10-06-2013      0
# 10-08-2010    271
# 10-10-2013    271
# 10-12-2013      0
# dtype: int64

# %%
df.fillna(value=0,inplace=True)

# %%
df['30-09-2013' ][30]
# Out:
# 0.0

# %%
d=pd.read_csv('D:\dressdataset.csv')

# %%
d.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    237
# 28-09-2013      0
# 30-09-2013    273
# 10-02-2013    275
# 10-04-2013    274
# 10-06-2013      0
# 10-08-2010    271
# 10-10-2013    271
# 10-12-2013      0
# dtype: int64

# %%
#Task1
use task;
create table if not exists attribute( Dress_ID int,Style varchar(30),Price varchar(30),Rating int,Size varchar(30),Season varchar(30),NeckLine varchar(30),SleeveLength varchar(30),waiseline varchar(30),Material varchar(30),FabricType varchar(30),Decoration varchar(30),Pattern  varchar(30),Recommendation int);
select * from task.attribute;
commit;

LOAD DATA INFILE 'D:\AttributeDataSet.csv' INTO TABLE task.attribute
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\r\n'
ignore 1 lines;
describe task.attribute;
# Out:
#   Input In [24]
#     use task;
#         ^
# SyntaxError: invalid syntax

# %%
#Task2Do a bulk load for these 2 tables for respective dataset in mysql workbench/python
create database task;
use task;

create table dressdataset(Dress_ID INT,
	`29-08-2013` INT,
	`31-08-2013` INT,
	`09-02-2013` INT,
	`09-04-2013` INT,
	`09-06-2013`	INT,
	`09-08-2013` INT,	
	`09-10-2013`	INT,
	`09-12-2013` INT,
	`14-09-2013`	INT,
	`16-09-2013`	INT,
	`18-09-2013`	INT,
	`20-09-2013`	INT,
	`22-09-2013`	INT,
	`24-09-2013`	INT,
	`26-09-2013`	INT,
	`28-09-2013`	INT,
	`30-09-2013`	INT,
	`10-02-2013`	INT,
	`10-04-2013`	INT,
	`10-06-2013`	INT,
	`10-08-2010`	INT,
	`10-10-2013`	INT,
	`10-12-2013` INT);
select @@GLOBAL.secure_file_priv;
LOAD DATA INFILE 'D:/dress.csv' INTO TABLE task.dressdataset
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\r\n'
ignore 1 lines;
select * from task.dressdataset

# %%
#Task3
# !pip install mysql-connector-python

# %%
#Read these datasets in pandas as a dataframe
import mysql.connector as sql
db_connection = sql.connect(host='Localhost', database='task', user='root', password='mysqlpavithra86')
db_cursor = db_connection.cursor()
db_cursor.execute('SELECT * FROM dressdataset')
table_rows = db_cursor.fetchall()

dress = pd.DataFrame(table_rows,columns=['dress_id','29/8/2013', '31/8/2013', '2/9/2013','4/9/2013','6/9/2013','8/9/2013','10/9/2013',
                                        '12/9/2013','14/9/2013','16/9/2013','18/9/2013','20/9/2013','22/9/2013','24/9/2013'
                                        '24/9/2013','26/9/2013','28/9/2013','30/9/2013','2/10/2013','4/10/2013','6/10/2013',
                                        '8/10/2013','10/10/2013','12/10/2013'])

# %%
dress
# Out:
#        dress_id  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
# ...

# %%
#Read these datasets in pandas as a dataframe
import mysql.connector as sql

import pandas as pd

db_connection = sql.connect(host='Localhost', database='task', user='root', password='mysqlpavithra86')

db_cursor = db_connection.cursor()

db_cursor.execute('SELECT * FROM task.attribute')

table_rows = db_cursor.fetchall()


attribute = pd.DataFrame(table_rows,columns=['dress_id', 'style', 'price','rating','size','season','neckline',
                                        'sleevelength','waiseline','material','fabrictype','decoration',
                                        'patterntype','recommendation'])

# %%
attribute.head()
# Out:
#      dress_id    style    price  rating size  season neckline sleevelength  \
# 0  1006032852     Sexy      Low       5    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low       0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High       0    L  Automn   o-neck         full
# 3   966005983    Brief  Average       5    L  Spring   o-neck         full
# 4   876339541     cute      Low       5    M  Summer   o-neck    butterfly
#
#   waiseline       material fabrictype  decoration patterntype  recommendation
# 0    empire           null    chiffon     ruffles      animal               1
# 1   natural     microfiber       null     ruffles      animal               0
# 2   natural       polyster       null        null       print               0
# 3   natural           silk    chiffon  embroidary       print               1
# 4   natural  chiffonfabric    chiffon         bow         dot               0

# %%
#Task 5Convert Attribute Dataset in JSON Format (.to_json will be used)
attribute.to_json('att.json')

# %%
pwd

# %%
print('C:\\Users\\harz1\json_attribute.json')
# Out:
# C:\Users\harz1\json_attribute.json

# %%
pip install "pymongo[srv]"

# %%
pip install pymongo

# %%
#task 5 :
import pymongo
import json
from pymongo import MongoClient, InsertOne
client = pymongo.MongoClient("mongodb+srv://ineuron:passwordmongodb@cluster0.wopdm1v.mongodb.net/?retryWrites=true&w=majority")
db = client.test
database = client['task24']
collection = database['attribute']

with open(r'‪C:\Users\harz1\json_attribute.json','r') as file:
    file_data = json.load(file)
if isinstance(file_data, list):
    
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# %%
#task6:In SQL task, try to perform left join operation with Attribute dataset and dress dataset on column Dress_ID

joined_data = pd.merge(attribute,dress,how = 'left',on = 'dress_id')
print(joined_data)
#In sql:SELECT  * FROM attribute
   #LEFT JOIN dressdataset
   #ON attribute.Dress_ID = dressdataset.Dress_ID;
# Out:
#         dress_id    style    price  rating  size  season   neckline  \
# 0     1006032852     Sexy      Low       5     M  Summer     o-neck
# 1     1212192089   Casual      Low       0     L  Summer     o-neck
# 2     1190380701  vintage     High       0     L  Automn     o-neck
# 3      966005983    Brief  Average       5     L  Spring     o-neck
# 4      876339541     cute      Low       5     M  Summer     o-neck
# ...          ...      ...      ...     ...   ...     ...        ...
# 2195   722565148     Sexy      Low       4  free  Summer     o-neck
# 2196   722565148     Sexy      Low       4  free  Summer     o-neck
# 2197   532874347   Casual  Average       5     M  Summer     v-neck
# 2198   655464934   Casual  Average       5     L  winter  boat-neck
# 2199   919930954   Casual      Low       4  free  Summer     v-neck
#
#      sleevelength waiseline       material  ... 24/9/201324/9/2013 26/9/2013  \
# ...

# %%
# task7Write the SQL query to find out how many unique dress that we have based on Dress_ID
len(attribute['dress_id'].unique())
#In sql :select count(distinct(Dress_id)) from task.attribute;
# Out:
# 475

# %%
#task 8Try to find out how many dress is having recommendation as 0
print((attribute["recommendation"]==0).sum())
#in sql:select count(Recommendation) from task.attribute where Recommendation = 0;
# Out:
# 1160

# %%
#task  9#Find the total sales for each and every dress id
#Creating Column Total Sales for each Dress ID
dress1=dress.set_index('dress_id')
d=dress1.sum(axis=1)
print(d)
# Out:
# dress_id
# 1006032852    75979
# 1212192089    52256
# 1190380701      223
# 966005983     39691
# 876339541     44077
#               ...
# 713391965      8915
# 722565148     17508
# 532874347     12606
# 655464934      5167
# 919930954     12312
# Length: 500, dtype: int64

# %%
#Task10:Find out the third highest dress sold
d.sort_values( ascending=False)
#ANS:1006032852 is the dress id of the dress which is third highest sold with the num=    75979
# Out:
# dress_id
# 629131530     155927
# 735635595      91556
# 1006032852     75979
# 749031896      75346
# 737538048      57543
#                ...
# 1139064593        20
# 898316315         20
# 703395323         20
# 1124754999        19
# 907669618          4
# Length: 500, dtype: int64
